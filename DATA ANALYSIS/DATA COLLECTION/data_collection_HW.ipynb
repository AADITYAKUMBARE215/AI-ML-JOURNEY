# %%
import requests
URL = "https://jokefather.com/api/jokes/random"
response = requests.get(URL)
response
# Out:
# <Response [200]>

# %%
json_data = response.json()
json_data
# Out:
# {'id': '01JN5DCFRVYFC55NKFRWRW1S1Q',
#  'setup': 'Where do bees go to the bathroom?',
#  'punchline': 'The BP station.'}

# %%
import pandas as pd
df = pd.json_normalize(json_data)
df
# Out:
#                            id                              setup  \
# 0  01JN5DCFRVYFC55NKFRWRW1S1Q  Where do bees go to the bathroom?
#
#          punchline
# 0  The BP station.
